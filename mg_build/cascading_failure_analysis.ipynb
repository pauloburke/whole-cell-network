# %%
import networkx as nx
from pyvis import network as net
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from collections import Counter 
import openpyxl as xl
from cascadingfailureanalysis import *

# %%
g = nx.read_gml("networks/mg_net.gml")

# %%
d,r,_ = cascade_failure(g,'c_MG_356_MONOMER',target_reaction='cellular_division_reaction')
print(d,r)
# Out:
# 4 False

# %%
replication_reaction = 'cellular_division_reaction'
print(list(set([d['moltype'] for _,d in g.nodes(data=True) if d['type']=='m'])))
genes = {}
for n,d in g.nodes(data=True):
    if d['type']=='m':
        if d['moltype'] == "Imature Protein Monomer":
            gn = n.replace("_MONOMER","").replace("Imature_","")[2:]
            genes[gn] = n
        if d['moltype']=="RNA" and ("tRNA" in d['annotations'] or "rRNA" in d['annotations'] or "sRNA" in d['annotations']):
            gn = n[2:]
            genes[gn] = n
            
for n,m in genes.items():
    print(n,m)
            
wb = xl.load_workbook('mg_essentiality_basis.xlsx')
sh=wb['Sheet1']
for i in range(1,sh.max_row):
    gene = sh['A'+str(i+1)].value
    if gene in genes.keys():        
        sh['C'+str(i+1)].value = genes[gene]
wb.save('mg_essentiality.xlsx')
# Out:
# ['Peptide', 'Protein Monomer', 'Stimulus', 'Translation Complex', 'Replication Complex', 'DNA-Protein Complex', 'Imature Protein Monomer', 'RNA', 'DNA', 'Transcription Complex', 'Protein Complex', 'RNA Complex', 'Small Molecule']
# MG471 c_MG471
# MG483 c_MG483
# MG472 c_MG472
# MG488 c_MG488
# MG493 c_MG493
# MG501 c_MG501
# MG489 c_MG489
# MG492 c_MG492
# MG499 c_MG499
# MG490 c_MG490
# MG511 c_MG511
# MG502 c_MG502
# MG518 c_MG518
# MG475 c_MG475
# MG523 c_MG523
# MG513 c_MG513
# MG497 c_MG497
# MG496 c_MG496
# MG510 c_MG510
# MG507 c_MG507
# MG487 c_MG487
# MG519 c_MG519
# MG509 c_MG509
# MG495 c_MG495
# MG500 c_MG500
# MG_0004 c_MG_0004
# MG484 c_MG484
# MG520 c_MG520
# MG503 c_MG503
# MG514 c_MG514
# MG479 c_MG479
# MG506 c_MG506
# MG485 c_MG485
# MG508 c_MG508
# MG512 c_MG512
# MG486 c_MG486
# MG504 c_MG504
# MG_344 c_Imature_MG_344_MONOMER
# MG_245 c_Imature_MG_245_MONOMER
# MG_517 c_Imature_MG_517_MONOMER
# MG_310 c_Imature_MG_310_MONOMER
# MG_327 c_Imature_MG_327_MONOMER
# MG_212 c_Imature_MG_212_MONOMER
# MG_071 c_Imature_MG_071_MONOMER
# MG_300 c_Imature_MG_300_MONOMER
# MG_342 c_Imature_MG_342_MONOMER
# MG_145 c_Imature_MG_145_MONOMER
# MG_061 c_Imature_MG_061_MONOMER
# MG_124 c_Imature_MG_124_MONOMER
# MG_408 c_Imature_MG_408_MONOMER
# MG_171 c_Imature_MG_171_MONOMER
# MG_330 c_Imature_MG_330_MONOMER
# MG_130 c_Imature_MG_130_MONOMER
# MG_270 c_Imature_MG_270_MONOMER
# MG_009 c_Imature_MG_009_MONOMER
# MG_356 c_Imature_MG_356_MONOMER
# MG_448 c_Imature_MG_448_MONOMER
# MG_230 c_Imature_MG_230_MONOMER
# MG_037 c_Imature_MG_037_MONOMER
# MG_264 c_Imature_MG_264_MONOMER
# MG_430 c_Imature_MG_430_MONOMER
# MG_050 c_Imature_MG_050_MONOMER
# MG_253 c_Imature_MG_253_MONOMER
# MG_345 c_Imature_MG_345_MONOMER
# MG_378 c_Imature_MG_378_MONOMER
# MG_334 c_Imature_MG_334_MONOMER
# MG_462 c_Imature_MG_462_MONOMER
# MG_365 c_Imature_MG_365_MONOMER
# MG_266 c_Imature_MG_266_MONOMER
# MG_437 c_Imature_MG_437_MONOMER
# MG_297 c_Imature_MG_297_MONOMER
# MG_210 c_Imature_MG_210_MONOMER
# MG_0001 c_MG_0001
# MG_382 c_Imature_MG_382_MONOMER
# MG_077 c_Imature_MG_077_MONOMER
# MG_078 c_Imature_MG_078_MONOMER
# MG_079 c_Imature_MG_079_MONOMER
# MG_080 c_Imature_MG_080_MONOMER
# MG_321 c_Imature_MG_321_MONOMER
# MG_105 c_Imature_MG_105_MONOMER
# MG_052 c_Imature_MG_052_MONOMER
# MG_372 c_Imature_MG_372_MONOMER
# MG_053 c_Imature_MG_053_MONOMER
# MG_112 c_Imature_MG_112_MONOMER
# MG_186 c_Imature_MG_186_MONOMER
# MG_187 c_Imature_MG_187_MONOMER
# MG_188 c_Imature_MG_188_MONOMER
# MG_189 c_Imature_MG_189_MONOMER
# MG_226 c_Imature_MG_226_MONOMER
# MG_265 c_Imature_MG_265_MONOMER
# MG_229 c_Imature_MG_229_MONOMER
# MG_231 c_Imature_MG_231_MONOMER
# MG_049 c_Imature_MG_049_MONOMER
# MG_385 c_Imature_MG_385_MONOMER
# MG_287 c_Imature_MG_287_MONOMER
# MG_118 c_Imature_MG_118_MONOMER
# MG_275 c_Imature_MG_275_MONOMER
# MG_293 c_Imature_MG_293_MONOMER
# MG_107 c_Imature_MG_107_MONOMER
# MG_368 c_Imature_MG_368_MONOMER
# MG_172 c_Imature_MG_172_MONOMER
# MG_431 c_Imature_MG_431_MONOMER
# MG_302 c_Imature_MG_302_MONOMER
# MG_303 c_Imature_MG_303_MONOMER
# MG_304 c_Imature_MG_304_MONOMER
# MG_216 c_Imature_MG_216_MONOMER
# MG_316 c_Imature_MG_316_MONOMER
# MG_394 c_Imature_MG_394_MONOMER
# MG_042 c_Imature_MG_042_MONOMER
# MG_043 c_Imature_MG_043_MONOMER
# MG_044 c_Imature_MG_044_MONOMER
# MG_045 c_Imature_MG_045_MONOMER
# MG_278 c_Imature_MG_278_MONOMER
# MG_357 c_Imature_MG_357_MONOMER
# MG_014 c_Imature_MG_014_MONOMER
# MG_015 c_Imature_MG_015_MONOMER
# MG_336 c_Imature_MG_336_MONOMER
# MG_333 c_Imature_MG_333_MONOMER
# MG_066 c_Imature_MG_066_MONOMER
# MG_454 c_Imature_MG_454_MONOMER
# MG_039 c_Imature_MG_039_MONOMER
# MG_427 c_Imature_MG_427_MONOMER
# MG_038 c_Imature_MG_038_MONOMER
# MG_013 c_Imature_MG_013_MONOMER
# MG_369 c_Imature_MG_369_MONOMER
# MG_460 c_Imature_MG_460_MONOMER
# MG_137 c_Imature_MG_137_MONOMER
# MG_228 c_Imature_MG_228_MONOMER
# MG_407 c_Imature_MG_407_MONOMER
# MG_030 c_Imature_MG_030_MONOMER
# MG_006 c_Imature_MG_006_MONOMER
# MG_467 c_Imature_MG_467_MONOMER
# MG_468 c_Imature_MG_468_MONOMER
# MG_526 c_Imature_MG_526_MONOMER
# MG_215 c_Imature_MG_215_MONOMER
# MG_322 c_Imature_MG_322_MONOMER
# MG_323 c_Imature_MG_323_MONOMER
# MG_063 c_Imature_MG_063_MONOMER
# MG_390 c_Imature_MG_390_MONOMER
# MG_458 c_Imature_MG_458_MONOMER
# MG_410 c_Imature_MG_410_MONOMER
# MG_411 c_Imature_MG_411_MONOMER
# MG_412 c_Imature_MG_412_MONOMER
# MG_051 c_Imature_MG_051_MONOMER
# MG_023 c_Imature_MG_023_MONOMER
# MG_040 c_Imature_MG_040_MONOMER
# MG_119 c_Imature_MG_119_MONOMER
# MG_120 c_Imature_MG_120_MONOMER
# MG_121 c_Imature_MG_121_MONOMER
# MG_102 c_Imature_MG_102_MONOMER
# MG_227 c_Imature_MG_227_MONOMER
# MG_259 c_Imature_MG_259_MONOMER
# MG_225 c_Imature_MG_225_MONOMER
# MG_114 c_Imature_MG_114_MONOMER
# MG_301 c_Imature_MG_301_MONOMER
# MG_123 c_Imature_MG_123_MONOMER
# MG_240 c_Imature_MG_240_MONOMER
# MG_033 c_Imature_MG_033_MONOMER
# MG_179 c_Imature_MG_179_MONOMER
# MG_180 c_Imature_MG_180_MONOMER
# MG_181 c_Imature_MG_181_MONOMER
# MG_289 c_Imature_MG_289_MONOMER
# MG_290 c_Imature_MG_290_MONOMER
# MG_291 c_Imature_MG_291_MONOMER
# MG_041 c_Imature_MG_041_MONOMER
# MG_069 c_Imature_MG_069_MONOMER
# MG_429 c_Imature_MG_429_MONOMER
# MG_434 c_Imature_MG_434_MONOMER
# MG_351 c_Imature_MG_351_MONOMER
# MG_396 c_Imature_MG_396_MONOMER
# MG_383 c_Imature_MG_383_MONOMER
# MG_271 c_Imature_MG_271_MONOMER
# MG_272 c_Imature_MG_272_MONOMER
# MG_273 c_Imature_MG_273_MONOMER
# MG_274 c_Imature_MG_274_MONOMER
# MG_299 c_Imature_MG_299_MONOMER
# MG_128 c_Imature_MG_128_MONOMER
# MG_453 c_Imature_MG_453_MONOMER
# MG_276 c_Imature_MG_276_MONOMER
# MG_034 c_Imature_MG_034_MONOMER
# MG_398 c_Imature_MG_398_MONOMER
# MG_399 c_Imature_MG_399_MONOMER
# MG_400 c_Imature_MG_400_MONOMER
# MG_401 c_Imature_MG_401_MONOMER
# MG_402 c_Imature_MG_402_MONOMER
# MG_403 c_Imature_MG_403_MONOMER
# MG_404 c_Imature_MG_404_MONOMER
# MG_405 c_Imature_MG_405_MONOMER
# MG_111 c_Imature_MG_111_MONOMER
# MG_058 c_Imature_MG_058_MONOMER
# MG_062 c_Imature_MG_062_MONOMER
# MG_047 c_Imature_MG_047_MONOMER
# MG_0003 c_MG_0003
# MG_292 c_Imature_MG_292_MONOMER
# MG_249 c_Imature_MG_249_MONOMER
# MG_027 c_Imature_MG_027_MONOMER
# MG_141 c_Imature_MG_141_MONOMER
# MG_282 c_Imature_MG_282_MONOMER
# MG_021 c_Imature_MG_021_MONOMER
# MG_251 c_Imature_MG_251_MONOMER
# MG_136 c_Imature_MG_136_MONOMER
# MG_036 c_Imature_MG_036_MONOMER
# MG_194 c_Imature_MG_194_MONOMER
# MG_195 c_Imature_MG_195_MONOMER
# MG_035 c_Imature_MG_035_MONOMER
# MG_005 c_Imature_MG_005_MONOMER
# MG_126 c_Imature_MG_126_MONOMER
# MG_375 c_Imature_MG_375_MONOMER
# MG_283 c_Imature_MG_283_MONOMER
# MG_455 c_Imature_MG_455_MONOMER
# MG_113 c_Imature_MG_113_MONOMER
# MG_098 c_Imature_MG_098_MONOMER
# MG_099 c_Imature_MG_099_MONOMER
# MG_100 c_Imature_MG_100_MONOMER
# MG_324 c_Imature_MG_324_MONOMER
# MG_183 c_Imature_MG_183_MONOMER
# MG_020 c_Imature_MG_020_MONOMER
# MG_083 c_Imature_MG_083_MONOMER
# MG_104 c_Imature_MG_104_MONOMER
# MG_196 c_Imature_MG_196_MONOMER
# MG_026 c_Imature_MG_026_MONOMER
# MG_258 c_Imature_MG_258_MONOMER
# MG_435 c_Imature_MG_435_MONOMER
# MG_072 c_Imature_MG_072_MONOMER
# MG_106 c_Imature_MG_106_MONOMER
# MG_048 c_Imature_MG_048_MONOMER
# MG_055 c_Imature_MG_055_MONOMER
# MG_170 c_Imature_MG_170_MONOMER
# MG_277 c_Imature_MG_277_MONOMER
# MG_464 c_Imature_MG_464_MONOMER
# MG_476 c_Imature_MG_476_MONOMER
# MG_305 c_Imature_MG_305_MONOMER
# MG_109 c_Imature_MG_109_MONOMER
# MG_367 c_Imature_MG_367_MONOMER
# MG_465 c_Imature_MG_465_MONOMER
# MG_022 c_Imature_MG_022_MONOMER
# MG_177 c_Imature_MG_177_MONOMER
# MG_340 c_Imature_MG_340_MONOMER
# MG_341 c_Imature_MG_341_MONOMER
# MG_254 c_Imature_MG_254_MONOMER
# MG_498 c_Imature_MG_498_MONOMER
# MG_097 c_Imature_MG_097_MONOMER
# MG_235 c_Imature_MG_235_MONOMER
# MG_339 c_Imature_MG_339_MONOMER
# MG_262 c_Imature_MG_262_MONOMER
# MG_239 c_Imature_MG_239_MONOMER
# MG_391 c_Imature_MG_391_MONOMER
# MG_208 c_Imature_MG_208_MONOMER
# MG_046 c_Imature_MG_046_MONOMER
# MG_457 c_Imature_MG_457_MONOMER
# MG_173 c_Imature_MG_173_MONOMER
# MG_142 c_Imature_MG_142_MONOMER
# MGrrnA16S c_MGrrnA16S
# MGrrnA23S c_MGrrnA23S
# MGrrnA5S c_MGrrnA5S
# MG_089 c_Imature_MG_089_MONOMER
# MG_451 c_Imature_MG_451_MONOMER
# MG_433 c_Imature_MG_433_MONOMER
# MG_392 c_Imature_MG_392_MONOMER
# MG_393 c_Imature_MG_393_MONOMER
# MG_073 c_Imature_MG_073_MONOMER
# MG_206 c_Imature_MG_206_MONOMER
# MG_421 c_Imature_MG_421_MONOMER
# MG_358 c_Imature_MG_358_MONOMER
# MG_359 c_Imature_MG_359_MONOMER
# MG_059 c_Imature_MG_059_MONOMER
# MG_070 c_Imature_MG_070_MONOMER
# MG_157 c_Imature_MG_157_MONOMER
# MG_150 c_Imature_MG_150_MONOMER
# MG_168 c_Imature_MG_168_MONOMER
# MG_155 c_Imature_MG_155_MONOMER
# MG_481 c_Imature_MG_481_MONOMER
# MG_176 c_Imature_MG_176_MONOMER
# MG_088 c_Imature_MG_088_MONOMER
# MG_522 c_Imature_MG_522_MONOMER
# MG_087 c_Imature_MG_087_MONOMER
# MG_424 c_Imature_MG_424_MONOMER
# MG_164 c_Imature_MG_164_MONOMER
# MG_175 c_Imature_MG_175_MONOMER
# MG_165 c_Imature_MG_165_MONOMER
# MG_311 c_Imature_MG_311_MONOMER
# MG_446 c_Imature_MG_446_MONOMER
# MG_160 c_Imature_MG_160_MONOMER
# MG_090 c_Imature_MG_090_MONOMER
# MG_417 c_Imature_MG_417_MONOMER
# MG_092 c_Imature_MG_092_MONOMER
# MG_387 c_Imature_MG_387_MONOMER
# MG_143 c_Imature_MG_143_MONOMER
# MG_329 c_Imature_MG_329_MONOMER
# MG_335 c_Imature_MG_335_MONOMER
# MG_384 c_Imature_MG_384_MONOMER
# MG_442 c_Imature_MG_442_MONOMER
# MG_466 c_Imature_MG_466_MONOMER
# MG_234 c_Imature_MG_234_MONOMER
# MG_167 c_Imature_MG_167_MONOMER
# MG_362 c_Imature_MG_362_MONOMER
# MG_473 c_Imature_MG_473_MONOMER
# MG_418 c_Imature_MG_418_MONOMER
# MG_154 c_Imature_MG_154_MONOMER
# MG_198 c_Imature_MG_198_MONOMER
# MG_257 c_Imature_MG_257_MONOMER
# MG_151 c_Imature_MG_151_MONOMER
# MG_178 c_Imature_MG_178_MONOMER
# MG_174 c_Imature_MG_174_MONOMER
# MG_166 c_Imature_MG_166_MONOMER
# MG_082 c_Imature_MG_082_MONOMER
# MG_093 c_Imature_MG_093_MONOMER
# MG_426 c_Imature_MG_426_MONOMER
# MG_156 c_Imature_MG_156_MONOMER
# MG_158 c_Imature_MG_158_MONOMER
# MG_361 c_Imature_MG_361_MONOMER
# MG_162 c_Imature_MG_162_MONOMER
# MG_363 c_Imature_MG_363_MONOMER
# MG_152 c_Imature_MG_152_MONOMER
# MG_325 c_Imature_MG_325_MONOMER
# MG_153 c_Imature_MG_153_MONOMER
# MG_444 c_Imature_MG_444_MONOMER
# MG_161 c_Imature_MG_161_MONOMER
# MG_197 c_Imature_MG_197_MONOMER
# MG_159 c_Imature_MG_159_MONOMER
# MG_163 c_Imature_MG_163_MONOMER
# MG_232 c_Imature_MG_232_MONOMER
# MG_169 c_Imature_MG_169_MONOMER
# MG_081 c_Imature_MG_081_MONOMER
# MG_110 c_Imature_MG_110_MONOMER
# MG_012 c_Imature_MG_012_MONOMER
# MG_127 c_Imature_MG_127_MONOMER
# MG_139 c_Imature_MG_139_MONOMER
# MG_425 c_Imature_MG_425_MONOMER
# MG_236 c_Imature_MG_236_MONOMER
# MG_205 c_Imature_MG_205_MONOMER
# MG_001 c_Imature_MG_001_MONOMER
# MG_122 c_Imature_MG_122_MONOMER
# MG_250 c_Imature_MG_250_MONOMER
# MG_101 c_Imature_MG_101_MONOMER
# MG_003 c_Imature_MG_003_MONOMER
# MG_004 c_Imature_MG_004_MONOMER
# MG_203 c_Imature_MG_203_MONOMER
# MG_204 c_Imature_MG_204_MONOMER
# MG_094 c_Imature_MG_094_MONOMER
# MG_031 c_Imature_MG_031_MONOMER
# MG_261 c_Imature_MG_261_MONOMER
# MG_007 c_Imature_MG_007_MONOMER
# MG_315 c_Imature_MG_315_MONOMER
# MG_419 c_Imature_MG_419_MONOMER
# MG_428 c_Imature_MG_428_MONOMER
# MG_469 c_Imature_MG_469_MONOMER
# MG_213 c_Imature_MG_213_MONOMER
# MG_214 c_Imature_MG_214_MONOMER
# MG_298 c_Imature_MG_298_MONOMER
# MG_191 c_Imature_MG_191_MONOMER
# MG_312 c_Imature_MG_312_MONOMER
# MG_217 c_Imature_MG_217_MONOMER
# MG_318 c_Imature_MG_318_MONOMER
# MG_386 c_Imature_MG_386_MONOMER
# MG_317 c_Imature_MG_317_MONOMER
# MG_218 c_Imature_MG_218_MONOMER
# MG_192 c_Imature_MG_192_MONOMER
# MG_470 c_Imature_MG_470_MONOMER
# MG_221 c_Imature_MG_221_MONOMER
# MG_224 c_Imature_MG_224_MONOMER
# MG_252 c_Imature_MG_252_MONOMER
# MG_096 c_Imature_MG_096_MONOMER
# MG_371 c_Imature_MG_371_MONOMER
# MG_029 c_Imature_MG_029_MONOMER
# MG_019 c_Imature_MG_019_MONOMER
# MG_010 c_Imature_MG_010_MONOMER
# MG_144 c_Imature_MG_144_MONOMER
# MG_211 c_Imature_MG_211_MONOMER
# MG_461 c_Imature_MG_461_MONOMER
# MG_115 c_Imature_MG_115_MONOMER
# MG_149 c_Imature_MG_149_MONOMER
# MG_409 c_Imature_MG_409_MONOMER
# MG_326 c_Imature_MG_326_MONOMER
# MG_447 c_Imature_MG_447_MONOMER
# MG_135 c_Imature_MG_135_MONOMER
# MG_478 c_Imature_MG_478_MONOMER
# MG_364 c_Imature_MG_364_MONOMER
# MG_450 c_Imature_MG_450_MONOMER
# MG_309 c_Imature_MG_309_MONOMER
# MG_084 c_Imature_MG_084_MONOMER
# MG_134 c_Imature_MG_134_MONOMER
# MG_267 c_Imature_MG_267_MONOMER
# MG_064 c_Imature_MG_064_MONOMER
# MG_515 c_Imature_MG_515_MONOMER
# MG_117 c_Imature_MG_117_MONOMER
# MG_060 c_Imature_MG_060_MONOMER
# MG_182 c_Imature_MG_182_MONOMER
# MG_397 c_Imature_MG_397_MONOMER
# MG_242 c_Imature_MG_242_MONOMER
# MG_024 c_Imature_MG_024_MONOMER
# MG_284 c_Imature_MG_284_MONOMER
# MG_319 c_Imature_MG_319_MONOMER
# MG_373 c_Imature_MG_373_MONOMER
# MG_441 c_Imature_MG_441_MONOMER
# MG_237 c_Imature_MG_237_MONOMER
# MG_263 c_Imature_MG_263_MONOMER
# MG_086 c_Imature_MG_086_MONOMER
# MG_011 c_Imature_MG_011_MONOMER
# MG_525 c_Imature_MG_525_MONOMER
# MG_279 c_Imature_MG_279_MONOMER
# MG_440 c_Imature_MG_440_MONOMER
# MG_095 c_Imature_MG_095_MONOMER
# MG_380 c_Imature_MG_380_MONOMER
# MG_246 c_Imature_MG_246_MONOMER
# MG_281 c_Imature_MG_281_MONOMER
# MG_338 c_Imature_MG_338_MONOMER
# MG_129 c_Imature_MG_129_MONOMER
# MG_054 c_Imature_MG_054_MONOMER
# MG_147 c_Imature_MG_147_MONOMER
# MG_286 c_Imature_MG_286_MONOMER
# MG_320 c_Imature_MG_320_MONOMER
# MG_260 c_Imature_MG_260_MONOMER
# MG_032 c_Imature_MG_032_MONOMER
# MG_091 c_Imature_MG_091_MONOMER
# MG_018 c_Imature_MG_018_MONOMER
# MG_002 c_Imature_MG_002_MONOMER
# MG_328 c_Imature_MG_328_MONOMER
# MG_028 c_Imature_MG_028_MONOMER
# MG_332 c_Imature_MG_332_MONOMER
# MG_346 c_Imature_MG_346_MONOMER
# MG_482 c_Imature_MG_482_MONOMER
# MG_076 c_Imature_MG_076_MONOMER
# MG_477 c_Imature_MG_477_MONOMER
# MG_280 c_Imature_MG_280_MONOMER
# MG_146 c_Imature_MG_146_MONOMER
# MG_207 c_Imature_MG_207_MONOMER
# MG_521 c_Imature_MG_521_MONOMER
# MG_248 c_Imature_MG_248_MONOMER
# MG_348 c_Imature_MG_348_MONOMER
# MG_456 c_Imature_MG_456_MONOMER
# MG_354 c_Imature_MG_354_MONOMER
# MG_185 c_Imature_MG_185_MONOMER
# MG_068 c_Imature_MG_068_MONOMER
# MG_347 c_Imature_MG_347_MONOMER
# MG_140 c_Imature_MG_140_MONOMER
# MG_480 c_Imature_MG_480_MONOMER
# MG_074 c_Imature_MG_074_MONOMER
# MG_438 c_Imature_MG_438_MONOMER
# MG_414 c_Imature_MG_414_MONOMER
# MG_314 c_Imature_MG_314_MONOMER
# MG_337 c_Imature_MG_337_MONOMER
# MG_395 c_Imature_MG_395_MONOMER
# MG_256 c_Imature_MG_256_MONOMER
# MG_360 c_Imature_MG_360_MONOMER
# MG_296 c_Imature_MG_296_MONOMER
# MG_219 c_Imature_MG_219_MONOMER
# MG_370 c_Imature_MG_370_MONOMER
# MG_313 c_Imature_MG_313_MONOMER
# MG_294 c_Imature_MG_294_MONOMER
# MG_238 c_Imature_MG_238_MONOMER
# MG_343 c_Imature_MG_343_MONOMER
# MG_116 c_Imature_MG_116_MONOMER
# MG_459 c_Imature_MG_459_MONOMER
# MG_295 c_Imature_MG_295_MONOMER
# MG_306 c_Imature_MG_306_MONOMER
# MG_494 c_Imature_MG_494_MONOMER
# MG_202 c_Imature_MG_202_MONOMER
# MG_247 c_Imature_MG_247_MONOMER
# MG_269 c_Imature_MG_269_MONOMER
# MG_524 c_Imature_MG_524_MONOMER
# MG_132 c_Imature_MG_132_MONOMER
# MG_268 c_Imature_MG_268_MONOMER
# MG_201 c_Imature_MG_201_MONOMER
# MG_516 c_Imature_MG_516_MONOMER
# MG_379 c_Imature_MG_379_MONOMER
# MG_255 c_Imature_MG_255_MONOMER
# MG_349 c_Imature_MG_349_MONOMER
# MG_422 c_Imature_MG_422_MONOMER
# MG_352 c_Imature_MG_352_MONOMER
# MG_366 c_Imature_MG_366_MONOMER
# MG_233 c_Imature_MG_233_MONOMER
# MG_439 c_Imature_MG_439_MONOMER
# MG_241 c_Imature_MG_241_MONOMER
# MG_209 c_Imature_MG_209_MONOMER
# MG_133 c_Imature_MG_133_MONOMER
# MG_307 c_Imature_MG_307_MONOMER
# MG_452 c_Imature_MG_452_MONOMER
# MG_505 c_Imature_MG_505_MONOMER
# MG_057 c_Imature_MG_057_MONOMER
# MG_331 c_Imature_MG_331_MONOMER
# MG_432 c_Imature_MG_432_MONOMER
# MG_474 c_Imature_MG_474_MONOMER
# MG_025 c_Imature_MG_025_MONOMER
# MG_445 c_Imature_MG_445_MONOMER
# MG_376 c_Imature_MG_376_MONOMER
# MG_463 c_Imature_MG_463_MONOMER
# MG_103 c_Imature_MG_103_MONOMER
# MG_285 c_Imature_MG_285_MONOMER
# MG_008 c_Imature_MG_008_MONOMER
# MG_389 c_Imature_MG_389_MONOMER
# MG_075 c_Imature_MG_075_MONOMER
# MG_308 c_Imature_MG_308_MONOMER
# MG_200 c_Imature_MG_200_MONOMER
# MG_065 c_Imature_MG_065_MONOMER
# MG_243 c_Imature_MG_243_MONOMER
# MG_220 c_Imature_MG_220_MONOMER
# MG_350 c_Imature_MG_350_MONOMER
# MG_125 c_Imature_MG_125_MONOMER
# MG_355 c_Imature_MG_355_MONOMER
# MG_377 c_Imature_MG_377_MONOMER
# MG_067 c_Imature_MG_067_MONOMER
# MG_423 c_Imature_MG_423_MONOMER
# MG_443 c_Imature_MG_443_MONOMER
# MG_108 c_Imature_MG_108_MONOMER
# MG_374 c_Imature_MG_374_MONOMER
# MG_223 c_Imature_MG_223_MONOMER
# MG_138 c_Imature_MG_138_MONOMER
# MG_199 c_Imature_MG_199_MONOMER
# MG_184 c_Imature_MG_184_MONOMER
# MG_491 c_Imature_MG_491_MONOMER
# MG_406 c_Imature_MG_406_MONOMER
# MG_190 c_Imature_MG_190_MONOMER
# MG_381 c_Imature_MG_381_MONOMER
# MG_388 c_Imature_MG_388_MONOMER
# MG_222 c_Imature_MG_222_MONOMER
# MG_353 c_Imature_MG_353_MONOMER
# MG_056 c_Imature_MG_056_MONOMER
# MG_288 c_Imature_MG_288_MONOMER
# MG_148 c_Imature_MG_148_MONOMER
# MG_085 c_Imature_MG_085_MONOMER
# MG_244 c_Imature_MG_244_MONOMER

# %%
gene_is_essential = {n:cascade_failure(g,m,target_reaction=replication_reaction)[1] for n,m in genes.items()}

# %%
label = {True:"Y",False:"N"}

for i in range(1,sh.max_row):
    gene = sh['A'+str(i+1)].value
    if gene in gene_is_essential.keys():        
        sh['F'+str(i+1)].value = label[gene_is_essential[gene]]
wb.save('mg_essentiality.xlsx')

# %%
double_gene_is_essential = gene_is_essential.copy()
double_deletions_essentiality = []
non_essential_genes = [n for n,m in double_gene_is_essential.items() if not m]
print("Non essential genes",len(non_essential_genes))
for i in range(len(non_essential_genes)-1):
    for j in range(i,len(non_essential_genes)):
        g_tuple = [non_essential_genes[i],non_essential_genes[j]]
        m = [genes[g] for g in g_tuple]
        if cascade_failure(g,m,target_reaction=replication_reaction)[1]:
            double_deletions_essentiality.append(g_tuple)
for gs in double_deletions_essentiality:
    double_gene_is_essential[gs[0]] = True
    double_gene_is_essential[gs[1]] = True
print("Pairs of essential genes",len(double_deletions_essentiality))
# Out:
# Non essential genes 322
# Pairs of essential genes 20

# %%
for i in range(1,sh.max_row):
    gene = sh['A'+str(i+1)].value
    if gene in gene_is_essential.keys():        
        sh['H'+str(i+1)].value = label[double_gene_is_essential[gene]]
wb.save('mg_essentiality.xlsx')

# %%
pair_g = nx.Graph()
edges = [tuple(e) for e in double_deletions_essentiality]
pair_g.add_edges_from(edges)
nx.write_gml(pair_g,'networks/mg_double_deletion_essential.gml')
nx.write_graphml(pair_g,'networks/mg_double_deletion_essential.graphml')

# %%
pair_g = nx.read_gml('networks/mg_double_deletion_essential.gml')
pyviz_g = net.Network(notebook=True)
pyviz_g.from_nx(pair_g)
pyviz_g.show_buttons(filter_=['physics'])
pyviz_g.show("pair_genes.html")
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="pair_genes.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
print(pair_g.nodes())
# Out:
# ['MG_245', 'MG_013', 'MG_071', 'MG_324', 'MG_183', 'MG_020', 'MG_239', 'MG_391', 'MG_208', 'MG_046', 'MG_322', 'MG_323']

# %%
#fmet_nodes = [n for n in g.nodes() if 'FMET' in n]
#print(fmet_nodes)
#fmet_nodes = ['c_FMET','c_MG488_FMET','c_MG_245_MONOMER','c_MG_013_DIMER']
#fmet_reactions = []
#for m in fmet_nodes:
#    for key in g.successors(m):
#        fmet_reactions.append(key)
#    for key in g.predecessors(m):
#        fmet_reactions.append(key)
#fmet_reactions = list(set([r for r in fmet_reactions if "Degradation" not in r and 'Elongation' not in r]))
#print(fmet_reactions)
fmet_reaction = ['FthC', 'MG488_Formyltransferase', 'FMETHs', 'FTHFS', 'MG_013_DIMER_BIOSYNTHESIS', 'FolD1', 'FMETHs_rev', 'FolD1_rev', 'FthC_rev', 'FolD2', 'FolD2_rev','MG488_FMET_Degradation']
fmet_net_nodes = fmet_reaction[:]
for r in fmet_reaction:
    for key in g.successors(r):
        fmet_net_nodes.append(key)
    for key in g.predecessors(r):
        fmet_net_nodes.append(key)
fmet_net_nodes = list(set(fmet_net_nodes))
fmet_net = g.subgraph(fmet_net_nodes)
nx.write_gml(fmet_net,'networks/mg_fmet_subnet.gml')
nx.write_graphml(fmet_net,'networks/mg_fmet_subnet.graphml')
print(fmet_net_nodes)
# Out:
# ['FolD2', 'MG488_FMET_Degradation', 'c_FMET', 'c_MG_083_MONOMER', 'c_CMP', 'c_H', 'FolD1_rev', 'c_THF', 'c_FOR', 'FolD1', 'c_NADP', 'MG488_Formyltransferase', 'MG_013_DIMER_BIOSYNTHESIS', 'c_NADPH', 'c_ATP', 'c_MG488_FMET', 'c_MG488_MET', 'c_GMP', 'c_FTHF10', 'FthC', 'FMETHs', 'c_H2O', 'c_MET', 'c_AMP', 'c_PI', 'FTHFS', 'FolD2_rev', 'FMETHs_rev', 'c_MG_245_MONOMER', 'c_MG_013_DIMER', 'c_UMP', 'c_ADP', 'c_METTHF', 'c_MG_013_MONOMER', 'c_MG_365_MONOMER', 'c_METHF', 'c_MG_104_MONOMER', 'FthC_rev']

# %%
#knockout_damage = {}
#knockout_essential = {}
#for node in [m for m in g.nodes()]:
#    d,r,_ = cascade_failure(g,node,target_reaction=replication_reaction)
#    knockout_damage[node] = d
#    knockout_essential[node] = r
#nx.set_node_attributes(g, knockout_damage, 'knockoutDamage')
#nx.set_node_attributes(g, knockout_damage, 'singleKnockoutEssential')

# %%
#g = nx.write_gml(g,"mg_net.gml")

# %%
net_file = "networks/mg_net.gml"
experimental_file = "mg_essentiality.xlsx"
replication_reaction = 'cellular_division_reaction'
p_step,p_max = '0.02','1.02'
replicates = 10
output_file = "ss.dat"
str_replicates = " ".join([str(i) for i in range(replicates)])

parameters = " ::: ".join([net_file,experimental_file,p_step,p_max,replication_reaction])
with open(output_file,"w") as f:
    f.write("#p\t replica\t essentials\t correct\t fp\t fn\n")
# %time !parallel -j10 python3 randomized_gene_essentiality.py ::: {parameters} ::: {str_replicates} >> {output_file}
# Out:
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = "en_US:en",
# 	LC_ALL = (unset),
# 	LC_TIME = "pt_BR.UTF-8",
# 	LC_MONETARY = "pt_BR.UTF-8",
# 	LC_CTYPE = "C.UTF-8",
# 	LC_ADDRESS = "pt_BR.UTF-8",
# 	LC_TELEPHONE = "pt_BR.UTF-8",
# 	LC_NAME = "pt_BR.UTF-8",
# 	LC_MEASUREMENT = "pt_BR.UTF-8",
# 	LC_IDENTIFICATION = "pt_BR.UTF-8",
# 	LC_NUMERIC = "pt_BR.UTF-8",
# 	LC_PAPER = "pt_BR.UTF-8",
# 	LANG = "en_US.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to a fallback locale ("en_US.UTF-8").
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = "en_US:en",
# 	LC_ALL = (unset),
# 	LC_TIME = "pt_BR.UTF-8",
# 	LC_MONETARY = "pt_BR.UTF-8",
# 	LC_CTYPE = "C.UTF-8",
# 	LC_ADDRESS = "pt_BR.UTF-8",
# 	LC_TELEPHONE = "pt_BR.UTF-8",
# 	LC_NAME = "pt_BR.UTF-8",
# 	LC_MEASUREMENT = "pt_BR.UTF-8",
# 	LC_IDENTIFICATION = "pt_BR.UTF-8",
# 	LC_NUMERIC = "pt_BR.UTF-8",
# 	LC_PAPER = "pt_BR.UTF-8",
# 	LANG = "en_US.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to a fallback locale ("en_US.UTF-8").
# CPU times: user 4min 58s, sys: 46.5 s, total: 5min 44s
# Wall time: 6h 13min 22s
